# %% [markdown]
# # Logistic Regression On Iris Dataset
# Iris is an open source dataset available on kaggle [kaggle.com/datasets]

# %%
import torch
print(torch.cuda.get_device_name())
# Out:
# NVIDIA GeForce RTX 3050 Ti Laptop GPU

# %% [markdown]
# Imports of important libraries</br>
# pandas : data manipulation</br>
# tensorflow : base framework/library</br>
# matplotlib : data visualization</br>

# %%
import pandas
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# Configuration of GPU devices</br>
# If GPU is not available don't run following cell

# %%
tf.config.PhysicalDevice('GPU:0',device_type='GPU')
# Out:
# PhysicalDevice(name='GPU:0', device_type='GPU')

# %% [markdown]
# Reading data from CSV file using pandas read_csv function
#
# read_csv auto converts data into dataframe

# %%
data = pandas.read_csv("./Iris.csv")
print(data.head(10))
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %% [markdown]
# Above we can see 4 features of Iris dataset</br>
#
# and they are seperated into 3 classes as following...

# %%
plt.hist(data['Species'])
# Out:
# (array([50.,  0.,  0.,  0.,  0., 50.,  0.,  0.,  0., 50.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Each class have 50 examples to train and test</br>
#
# Following we have plot for each feature in single plot

# %%
plt.plot(data['SepalLengthCm'],label='S_L')
plt.plot(data['SepalWidthCm'],label='S_W')
plt.plot(data['PetalLengthCm'],label='P_L')
plt.plot(data['PetalWidthCm'],label='P_W')

#plt.axvline(50.0)
#plt.axvline(100.0)

plt.legend()

# %% [markdown]
# Now from here we have seperate plot for each feature</br>
#
# We can see how each feature seperates example from respective classes

# %%
plt.plot(data['SepalLengthCm'])

# %%
plt.plot(data['SepalWidthCm'])

# %%
plt.plot(data['PetalLengthCm'])

# %%
plt.plot(data['PetalWidthCm'])
